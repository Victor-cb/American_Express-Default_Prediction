# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_parquet("../data/processed/train_fs.parquet")

# %%
def read_file(path = '', usecols = None):
    # LOAD DATAFRAME
    if usecols is not None: df = pd.read_parquet(path, columns=usecols)
    else: df = pd.read_parquet(path)
    # REDUCE DTYPE FOR CUSTOMER AND DATE
    df.S_2 = pd.to_datetime( df.S_2 )
    # SORT BY CUSTOMER AND DATE (so agg('last') works correctly)
    df = df.sort_values(['customer_ID','S_2'])
    df = df.reset_index(drop=True)
    # FILL NAN
    df = df.fillna(-127) 
    print('shape of data:', df.shape)
    
    return df

print('Reading train data...')
TRAIN_PATH = '../data/processed/train_fs.parquet'
train = read_file(path = TRAIN_PATH)
# Out:
# Reading train data...
# shape of data: (5531451, 168)

# %%
# FEATURES
FEATURES = train.columns[2:]
print(f'There are {len(FEATURES)} features!')
# Out:
# There are 166 features!

# %%
def process_and_feature_engineer(df):
    # FEATURE ENGINEERING FROM 
    # https://www.kaggle.com/code/huseyincot/amex-agg-data-how-it-created
    all_cols = [c for c in list(df.columns) if c not in ['customer_ID','S_2']]
    cat_features = ["B_30","B_38","D_114","D_116","D_117","D_120","D_126","D_63","D_64","D_66","D_68"]
    num_features = [col for col in all_cols if col not in cat_features]

    test_num_agg = df.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    test_num_agg.columns = ['_'.join(x) for x in test_num_agg.columns]

    test_cat_agg = df.groupby("customer_ID")[cat_features].agg(['count', 'last', 'nunique'])
    test_cat_agg.columns = ['_'.join(x) for x in test_cat_agg.columns]

    df = pd.concat([test_num_agg, test_cat_agg], axis=1)
    del test_num_agg, test_cat_agg
    print('shape after engineering', df.shape )
    
    return df

train = process_and_feature_engineer(train)
# Out:
# shape after engineering (458913, 808)

# %% [markdown]
# ## First set of features added

# %%
train.to_parquet("../data/processed/train_feature.parquet")

# %% [markdown]
# ## Feature WOE && IV

# %%
def iv_woe(data, target, bins=10, show_woe=False):
    
    #Empty Dataframe
    newDF,woeDF = pd.DataFrame(), pd.DataFrame()
    
    #Extract Column Names
    cols = data.columns
    
    #Run WOE and IV on all the independent variables
    for ivars in cols[~cols.isin([target])]:
        if (data[ivars].dtype.kind in 'bifc') and (len(np.unique(data[ivars]))>10):
            binned_x = pd.qcut(data[ivars], bins,  duplicates='drop')
            d0 = pd.DataFrame({'x': binned_x, 'y': data[target]})
        else:
            d0 = pd.DataFrame({'x': data[ivars], 'y': data[target]})

        
        # Calculate the number of events in each group (bin)
        d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})
        d.columns = ['Cutoff', 'N', 'Events']
        
        # Calculate % of events in each group.
        d['% of Events'] = np.maximum(d['Events'], 0.5) / d['Events'].sum()

        # Calculate the non events in each group.
        d['Non-Events'] = d['N'] - d['Events']
        # Calculate % of non events in each group.
        d['% of Non-Events'] = np.maximum(d['Non-Events'], 0.5) / d['Non-Events'].sum()

        # Calculate WOE by taking natural log of division of % of non-events and % of events
        d['WoE'] = np.log(d['% of Events']/d['% of Non-Events'])
        d['IV'] = d['WoE'] * (d['% of Events'] - d['% of Non-Events'])
        d.insert(loc=0, column='Variable', value=ivars)
        print("Information value of " + ivars + " is " + str(round(d['IV'].sum(),6)))
        temp =pd.DataFrame({"Variable" : [ivars], "IV" : [d['IV'].sum()]}, columns = ["Variable", "IV"])
        newDF=pd.concat([newDF,temp], axis=0)
        woeDF=pd.concat([woeDF,d], axis=0)

        #Show WOE Table
        if show_woe == True:
            print(d)
    return newDF, woeDF

# %%
newdf, woedf = iv_woe(data=train, target='target')
# Out:
# Information value of customer_ID is 6.100698
# Information value of S_2 is 0.008395
# Information value of P_2 is 2.982891
# Information value of D_39 is 0.10178
# Information value of B_1 is 1.291884
# Information value of B_2 is 1.289213
# Information value of R_1 is 0.603611
# Information value of S_3 is 0.836053
# Information value of D_41 is 0.290369
# Information value of B_3 is 1.332385
# Information value of D_42 is 1.575721
# Information value of D_43 is 0.50723
# Information value of D_44 is 1.41223
# Information value of B_4 is 1.16503
# Information value of D_45 is 0.675468
# Information value of B_5 is 0.323848
# Information value of R_2 is 0.315512
# Information value of D_46 is 0.335184
# Information value of D_47 is 0.500697
# Information value of D_48 is 1.971191
# Information value of D_49 is 0.0
# Information value of B_6 is 1.495013
# Information value of B_7 is 1.576316
# Information value of B_8 is 0.470344
# Information value of D_50 is 0.523316
# Information value of D_51 is 0.576941
# Information value of B_9 is 1.442702
# Information value of R_3 is 0.387472
# Information value of D_52 is 0.784062
# Information value of P_3 is 0.442689
# Information value of B_10 is 1.541482
# Information value of D_53 is 0.451527
# Information value of S_5 is 0.196784
# Information value of B_11 is 1.206137
# Information value of S_6 is 0.057305
# Information value of D_54 is 0.0
# Information value of R_4 is 0.227856
# Information value of B_12 is 0.245049
# Information value of S_8 is 0.281663
# Information value of D_56 is 0.366383
# Information value of B_13 is 0.184285
# Information value of R_5 is 0.0
# Information value of D_58 is 1.187391
# Information value of S_9 is 0.028229
# Information value of B_14 is 0.537021
# Information value of D_59 is 0.200892
# Information value of D_60 is 0.494721
# Information value of D_61 is 1.659157
# Information value of S_11 is 0.069861
# Information value of D_62 is 1.533271
# Information value of D_63 is 0.042769
# Information value of D_64 is 0.214947
# Information value of D_65 is 0.0
# Information value of B_16 is 0.905794
# Information value of B_17 is 0.381477
# Information value of B_19 is 0.859619
# Information value of D_66 is 0.017383
# Information value of D_68 is 0.203751
# Information value of S_12 is 0.024849
# Information value of R_6 is 0.093607
# Information value of S_13 is 0.086802
# Information value of B_21 is 0.02421
# Information value of D_69 is 0.020655
# Information value of B_22 is 0.691388
# Information value of D_70 is 0.446919
# Information value of D_71 is 0.260377
# Information value of D_72 is 0.226063
# Information value of S_15 is 0.32952
# Information value of D_73 is 0.177206
# Information value of P_4 is 0.206166
# Information value of D_76 is 1.057218
# Information value of B_24 is 0.028385
# Information value of R_7 is 0.0
# Information value of B_25 is 0.579562
# Information value of B_26 is 0.069764
# Information value of D_78 is 0.399997
# Information value of D_79 is 0.236283
# Information value of R_8 is 0.0
# Information value of R_9 is 0.0
# Information value of S_16 is 0.024191
# Information value of D_80 is 0.015185
# Information value of R_10 is 0.0
# Information value of R_11 is 0.0
# Information value of B_27 is 3.1e-05
# Information value of D_81 is 0.203317
# Information value of D_82 is 0.02171
# Information value of S_17 is 0.001402
# Information value of R_12 is 0.0
# Information value of B_28 is 0.614213
# Information value of R_13 is 0.0
# Information value of D_83 is 0.03971
# Information value of R_14 is 0.0
# Information value of R_15 is 0.073195
# Information value of D_84 is 0.275178
# Information value of R_16 is 0.0
# Information value of B_29 is 0.005402
# Information value of B_30 is 0.601625
# Information value of S_18 is 0.000557
# Information value of D_86 is 0.034015
# Information value of D_87 is 0.00688
# Information value of R_17 is 0.0
# Information value of R_18 is 0.0
# Information value of D_88 is 0.380604
# Information value of B_31 is 0.01586
# Information value of S_19 is 0.000166
# Information value of R_19 is 0.04507
# Information value of B_32 is 0.045673
# Information value of S_20 is 0.078385
# Information value of R_20 is 0.103546
# Information value of R_21 is 0.104355
# Information value of D_89 is 0.085962
# Information value of R_22 is 0.018126
# Information value of R_23 is 0.001149
# Information value of D_91 is 0.158069
# Information value of D_92 is 0.241085
# Information value of D_93 is 0.00989
# Information value of D_94 is 0.053633
# Information value of R_24 is 0.101386
# Information value of R_25 is 0.017447
# Information value of D_96 is 0.026107
# Information value of S_22 is 0.626038
# Information value of S_23 is 0.44102
# Information value of S_25 is 0.489884
# Information value of S_26 is 0.078793
# Information value of D_102 is 0.086331
# Information value of D_103 is 0.087148
# Information value of D_105 is 0.009431
# Information value of D_106 is 0.0
# Information value of B_36 is 0.000824
# Information value of R_26 is 0.332928
# Information value of R_27 is 0.422139
# Information value of B_38 is 1.279814
# Information value of D_108 is 0.0
# Information value of D_109 is 0.004611
# Information value of D_110 is 0.075769
# Information value of B_39 is 0.043415
# Information value of D_112 is 0.204157
# Information value of B_40 is 1.20772
# Information value of S_27 is 0.305437
# Information value of D_113 is 0.11342
# Information value of D_114 is 0.209452
# Information value of D_115 is 0.201979
# Information value of D_116 is 0.032382
# Information value of D_117 is 0.18646
# Information value of D_118 is 0.184151
# Information value of D_120 is 0.194074
# Information value of D_121 is 0.167923
# Information value of D_122 is 0.171631
# Information value of D_123 is 0.019095
# Information value of D_124 is 0.04416
# Information value of D_125 is 0.02328
# Information value of D_126 is 0.048179
# Information value of D_127 is 0.386721
# Information value of D_128 is 0.134154
# Information value of D_129 is 0.106281
# Information value of B_41 is 0.042585
# Information value of B_42 is 2.520457
# Information value of D_130 is 0.095898
# Information value of D_133 is 0.143472
# Information value of R_28 is 0.003221
# Information value of D_134 is 0.030054
# Information value of D_135 is 0.108593
# Information value of D_139 is 0.083562
# Information value of D_140 is 0.063495
# Information value of D_142 is 0.043756
# Information value of D_144 is 0.000347
# Information value of D_145 is 0.077741

# %%
import pandas as pd
import scipy.stats as stats

class CategoricalFeature():
    def __init__(self, df, feature):
        self.df = df
        self.feature = feature

    @property
    def df_lite(self):
        df_lite = self.df
        df_lite['bin'] = df_lite[self.feature].fillna('MISSING')
        return df_lite[['bin', 'target']]


class ContinuousFeature():
    def __init__(self, df, feature):
        self.df = df
        self.feature = feature
        self.bin_min_size = int(len(self.df) * 0.05)

    def __generate_bins(self, bins_num):
        df = self.df[[self.feature, 'target']]
        df['bin'] = pd.qcut(df[self.feature], bins_num, duplicates='drop') \
                    .apply(lambda x: x.left) \
                    .astype(float)
        return df

    def __generate_correct_bins(self, bins_max=20):
        for bins_num in range(bins_max, 1, -1):
            df = self.__generate_bins(bins_num)
            df_grouped = pd.DataFrame(df.groupby('bin') \
                                      .agg({self.feature: 'count',
                                            'target': 'sum'})) \
                                      .reset_index()
            r, p = stats.spearmanr(df_grouped['bin'], df_grouped['target'])

            if (
                    abs(r)==1 and                                                        # check if woe for bins are monotonic
                    df_grouped[self.feature].min() > self.bin_min_size                   # check if bin size is greater than 5%
                    and not (df_grouped[self.feature] == df_grouped['target']).any()      # check if number of good and bad is not equal to 0
            ):
                break

        return df

    @property
    def df_lite(self):
        df_lite = self.__generate_correct_bins()
        df_lite['bin'].fillna('MISSING', inplace=True)
        return df_lite[['bin', 'target']]

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('mode.chained_assignment', None)

class AttributeRelevance():
    def seq_palette(self, n_colors):
        return sns.cubehelix_palette(n_colors, start=.5, rot=-.75, reverse=True)

    def bulk_iv(self, feats, iv, woe_extremes=False):
        iv_dict = {}
        for f in feats:
            iv_df, iv_value = iv.calculate_iv(f)
            if woe_extremes:
                iv_dict[f.feature] = [iv_value, iv_df['woe'].min(), iv_df['woe'].max()]
                cols = ['iv', 'woe_min', 'woe_max']
            else:
                iv_dict[f.feature] = iv_value
                cols = ['iv']
        df = pd.DataFrame.from_dict(iv_dict, orient='index', columns=cols)
        return df

    def bulk_stats(self, feats, s):
        stats_dict = {}
        for f in feats:
            p_value, effect_size = s.calculate_chi(f)
            stats_dict[f.feature] = [p_value, effect_size]
        df = pd.DataFrame.from_dict(stats_dict, orient='index', columns=['p-value', 'effect_size'])
        return df

    def analyze(self, feats, iv, s=None, interpretation=False):
        df_iv = self.bulk_iv(feats, iv).sort_values(by='iv', ascending=False)
        if s is not None:
            df_stats = self.bulk_stats(feats, s)
            df_iv = df_iv.merge(df_stats, left_index=True, right_index=True)
        if interpretation:
            df_iv['iv_interpretation'] = df_iv['iv'].apply(iv.interpretation)
            if s is not None:
                df_iv['es_interpretation'] = df_iv['effect_size'].apply(s.interpretation)
        return df_iv

    def draw_iv(self, feats, iv):
        df = self.analyze(feats, iv)
        fig, ax = plt.subplots(figsize=(10, 6))
        sns.barplot(x=df.index, y='iv', data=df, palette=self.seq_palette(len(feats)))
        ax.set_title('IV values')
        plt.xticks(rotation=90)
        plt.show()

    def draw_woe_extremes(self, feats, iv):
        df = self.bulk_iv(feats, iv, woe_extremes=True).sort_values(by='iv', ascending=False)
        fig, ax = plt.subplots(figsize=(10, 6))
        sns.barplot(x=df.index, y='woe_min', data=df, palette=self.seq_palette(len(feats)))
        sns.barplot(x=df.index, y='woe_max', data=df, palette=self.seq_palette(len(feats)))
        ax.axhline(y=0, color='black', linewidth=1)
        ax.set_title('Range of WOE values')
        ax.set_ylabel('WOE')
        plt.xticks(rotation=90)
        plt.show()

    def draw_woe_multiplot(self, feats, iv):
        n = len(feats)
        nrows = int(np.ceil(n/3))
        fig, ax = plt.subplots(nrows=nrows, ncols=3, figsize=(15, nrows*4))
        for i in range(n):
            iv_df, iv_value = iv.calculate_iv(feats[i])
            sns.barplot(x=feats[i].feature, y='woe', data=iv_df, color='#455872', ax=fig.axes[i])

        for ax in fig.axes:
            plt.sca(ax)
            plt.xticks(rotation=50)

        plt.tight_layout()
        plt.show()

class Analysis():
    def seq_palette(self, n_colors):
        return sns.cubehelix_palette(n_colors, start=.5, rot=-.75, reverse=True)

    def group_by_feature(self, feat):
        df = feat.df_lite \
                            .groupby('bin') \
                            .agg({'target': ['count', 'sum']}) \
                            .reset_index()
        df.columns = [feat.feature, 'count', 'good']
        df['bad'] = df['count'] - df['good']
        return df

class StatsSignificance(Analysis):
    def calculate_chi(self, feat):
        df = self.group_by_feature(feat)
        df_chi = np.array(df[['good', 'bad']])
        n = df['count'].sum()

        chi = stats.chi2_contingency(df_chi)
        cramers_v = np.sqrt(chi[0] / n)          # assume that k=2 (good, bad)
        return chi[1], cramers_v

    @staticmethod
    def interpretation(cramers_v):
        if cramers_v < 0.1:
            return 'useless'
        elif cramers_v < 0.2:
            return 'weak'
        elif cramers_v < 0.4:
            return 'medium'
        elif cramers_v < 0.6:
            return 'strong'
        else:
            return 'very strong'

    def interpret_chi(self, feat):
        _, cramers_v = self.calculate_chi(feat)
        return self.interpretation(cramers_v)

    def print_chi(self, feat):
        p_value, cramers_v = self.calculate_chi(feat)
        print('P-value: %0.2f\nEffect size: %0.2f' % (p_value, cramers_v))
        print('%s is a %s predictor' % (feat.feature.capitalize(), self.interpretation(cramers_v)))


class IV(Analysis):
    @staticmethod
    def __perc_share(df, group_name):
        return df[group_name] / df[group_name].sum()

    def __calculate_perc_share(self, feat):
        df = self.group_by_feature(feat)
        df['perc_good'] = self.__perc_share(df, 'good')
        df['perc_bad'] = self.__perc_share(df, 'bad')
        df['perc_diff'] = df['perc_good'] - df['perc_bad']
        return df

    def __calculate_woe(self, feat):
        df = self.__calculate_perc_share(feat)
        df['woe'] = np.log(df['perc_good']/df['perc_bad'])
        df['woe'] = df['woe'].replace([np.inf, -np.inf], np.nan).fillna(0)
        return df

    def calculate_iv(self, feat):
        df = self.__calculate_woe(feat)
        df['iv'] = df['perc_diff'] * df['woe']
        return df, df['iv'].sum()

    def draw_woe(self, feat):
        iv_df, iv_value = self.calculate_iv(feat)
        fig, ax = plt.subplots(figsize=(10,6))
        sns.barplot(x=feat.feature, y='woe', data=iv_df, palette=self.seq_palette(len(iv_df.index)))
        ax.set_title('WOE visualization for: ' + feat.feature)
        plt.show()
        plt.show()

    @staticmethod
    def interpretation(iv):
        if iv < 0.02:
            return 'useless'
        elif iv < 0.1:
            return 'weak'
        elif iv < 0.3:
            return 'medium'
        elif iv < 0.5:
            return 'strong'
        else:
            return 'suspicious'

    def interpret_iv(self, feat):
        _, iv = self.calculate_iv(feat)
        return self.interpretation(iv)

    def print_iv(self, feat):
        _, iv = self.calculate_iv(feat)
        print('Information value: %0.2f' % iv)
        print('%s is a %s predictor' % (feat.feature.capitalize(), self.interpretation(iv)))

# %%
cat_cols = ['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68']


num_cols = [c for c in train.columns if c not in [cat_cols, "customer_ID", "S_2", "target"]]

# %%
len(cat_cols), len(num_cols)
# Out:
# (11, 165)

# %%
iv=IV()
df_iv = []
feature_iv= []

def woe_iv_dataframe(df):
   

    for c in df[FEATURES].columns:
        feats_dict={}
        
        if c in cat_cols:
            feats_dict={}
            feats_dict[c]= CategoricalFeature(df[FEATURES], c)
            feats_dict = list(feats_dict.values())
            iv_df, iv_value = iv.calculate_iv(feats_dict[0])
            df_iv.append(iv_value)
            feature_iv.append(c)
            iv_df.to_csv(f"../reports/woe_iv_features/categorical_iv_woe_{c}.csv")          
            del feats_dict,iv_df
        else:
            feats_dict[c] = ContinuousFeature(df[FEATURES], c)
            feats_dict = list(feats_dict.values())
            iv_df, iv_value = iv.calculate_iv(feats_dict[0])
            df_iv.append(iv_value)
            feature_iv.append(c)
            iv_df.to_csv(f"../reports/woe_iv_features/numerical_iv_woe_{c}.csv")          
            del feats_dict,iv_df
        print(c)
woe_iv_dataframe(train)
# Out:
# P_2
# D_39
# B_1
# B_2
# R_1
# S_3
# D_41
# B_3
# D_42
# D_43
# D_44
# B_4
# D_45
# B_5
# R_2
# D_46
# D_47
# D_48
# D_49
# B_6
# B_7
# B_8
# D_50
# D_51
# B_9
# R_3
# D_52
# P_3
# B_10
# D_53
# S_5
# B_11
# S_6
# D_54
# R_4
# B_12
# S_8
# D_56
# B_13
# R_5
# D_58
# S_9
# B_14
# D_59
# D_60
# D_61
# S_11
# D_62
# D_63
# D_64
# D_65
# B_16
# B_17
# B_19
# D_66
# D_68
# S_12
# R_6
# S_13
# B_21
# D_69
# B_22
# D_70
# D_71
# D_72
# S_15
# D_73
# P_4
# D_76
# B_24
# R_7
# B_25
# B_26
# D_78
# D_79
# R_8
# R_9
# S_16
# D_80
# R_10
# R_11
# B_27
# D_81
# D_82
# S_17
# R_12
# B_28
# R_13
# D_83
# R_14
# R_15
# D_84
# R_16
# B_29
# B_30
# S_18
# D_86
# D_87
# R_17
# R_18
# D_88
# B_31
# S_19
# R_19
# B_32
# S_20
# R_20
# R_21
# D_89
# R_22
# R_23
# D_91
# D_92
# D_93
# D_94
# R_24
# R_25
# D_96
# S_22
# S_23
# S_25
# S_26
# D_102
# D_103
# D_105
# D_106
# B_36
# R_26
# R_27
# B_38
# D_108
# D_109
# D_110
# B_39
# D_112
# B_40
# S_27
# D_113
# D_114
# D_115
# D_116
# D_117
# D_118
# D_120
# D_121
# D_122
# D_123
# D_124
# D_125
# D_126
# D_127
# D_128
# D_129
# B_41
# B_42
# D_130
# D_133
# R_28
# D_134
# D_135
# D_139
# D_140
# D_142
# D_144
# D_145
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\brito\OneDrive\Documentos\1 - Data Science\3 - Projeto\04 - American Express\notebooks\06-feature_engi.ipynb Cell 15 in <cell line: 26>()
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=23'>24</a>             del feats_dict,iv_df
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=24'>25</a>         print(c)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=25'>26</a> woe_iv_dataframe(train)
#
# c:\Users\brito\OneDrive\Documentos\1 - Data Science\3 - Projeto\04 - American Express\notebooks\06-feature_engi.ipynb Cell 15 in woe_iv_dataframe(df)
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=18'>19</a> feats_dict[c] = ContinuousFeature(df[FEATURES], c)
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=19'>20</a> feats_dict = list(feats_dict.values())
# ---> <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=20'>21</a> iv_df, iv_value = iv.calculate_iv(feats_dict[0])
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=21'>22</a> df_iv.append(iv_value)
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=22'>23</a> iv_df.to_csv(f"../reports/woe_iv_features/numerical_iv_woe_{c}.csv")
#
# c:\Users\brito\OneDrive\Documentos\1 - Data Science\3 - Projeto\04 - American Express\notebooks\06-feature_engi.ipynb Cell 15 in IV.calculate_iv(self, feat)
#     <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=142'>143</a> def calculate_iv(self, feat):
# --> <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=143'>144</a>     df = self.__calculate_woe(feat)
#     <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=144'>145</a>     df['iv'] = df['perc_diff'] * df['woe']
#     <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=145'>146</a>     return df, df['iv'].sum()
#
# c:\Users\brito\OneDrive\Documentos\1 - Data Science\3 - Projeto\04 - American Express\notebooks\06-feature_engi.ipynb Cell 15 in IV.__calculate_woe(self, feat)
#     <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=136'>137</a> def __calculate_woe(self, feat):
# --> <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=137'>138</a>     df = self.__calculate_perc_share(feat)
#     <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=138'>139</a>     df['woe'] = np.log(df['perc_good']/df['perc_bad'])
#     <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=139'>140</a>     df['woe'] = df['woe'].replace([np.inf, -np.inf], np.nan).fillna(0)
#
# c:\Users\brito\OneDrive\Documentos\1 - Data Science\3 - Projeto\04 - American Express\notebooks\06-feature_engi.ipynb Cell 15 in IV.__calculate_perc_share(self, feat)
#     <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=129'>130</a> def __calculate_perc_share(self, feat):
# --> <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=130'>131</a>     df = self.group_by_feature(feat)
#     <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=131'>132</a>     df['perc_good'] = self.__perc_share(df, 'good')
#     <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=132'>133</a>     df['perc_bad'] = self.__perc_share(df, 'bad')
#
# c:\Users\brito\OneDrive\Documentos\1 - Data Science\3 - Projeto\04 - American Express\notebooks\06-feature_engi.ipynb Cell 15 in Analysis.group_by_feature(self, feat)
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=82'>83</a> def group_by_feature(self, feat):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=83'>84</a>     df = feat.df_lite \
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=84'>85</a>                         .groupby('bin') \
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=85'>86</a>                         .agg({'target': ['count', 'sum']}) \
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=86'>87</a>                         .reset_index()
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=87'>88</a>     df.columns = [feat.feature, 'count', 'good']
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=88'>89</a>     df['bad'] = df['count'] - df['good']
#
# c:\Users\brito\OneDrive\Documentos\1 - Data Science\3 - Projeto\04 - American Express\notebooks\06-feature_engi.ipynb Cell 15 in ContinuousFeature.df_lite(self)
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=46'>47</a> @property
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=47'>48</a> def df_lite(self):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=48'>49</a>     df_lite = self.__generate_correct_bins()
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=49'>50</a>     df_lite['bin'].fillna('MISSING', inplace=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=50'>51</a>     return df_lite[['bin', 'target']]
#
# c:\Users\brito\OneDrive\Documentos\1 - Data Science\3 - Projeto\04 - American Express\notebooks\06-feature_engi.ipynb Cell 15 in ContinuousFeature.__generate_correct_bins(self, bins_max)
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=28'>29</a> def __generate_correct_bins(self, bins_max=20):
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=29'>30</a>     for bins_num in range(bins_max, 1, -1):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=30'>31</a>         df = self.__generate_bins(bins_num)
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=31'>32</a>         df_grouped = pd.DataFrame(df.groupby('bin') \
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=32'>33</a>                                   .agg({self.feature: 'count',
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=33'>34</a>                                         'target': 'sum'})) \
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=34'>35</a>                                   .reset_index()
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=35'>36</a>         r, p = stats.spearmanr(df_grouped['bin'], df_grouped['target'])
#
# c:\Users\brito\OneDrive\Documentos\1 - Data Science\3 - Projeto\04 - American Express\notebooks\06-feature_engi.ipynb Cell 15 in ContinuousFeature.__generate_bins(self, bins_num)
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=21'>22</a> def __generate_bins(self, bins_num):
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=22'>23</a>     df = self.df[[self.feature, 'target']]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=23'>24</a>     df['bin'] = pd.qcut(df[self.feature], bins_num, duplicates='drop') \
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=24'>25</a>                 .apply(lambda x: x.left) \
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=25'>26</a>                 .astype(float)
#      <a href='vscode-notebook-cell:/c%3A/Users/brito/OneDrive/Documentos/1%20-%20Data%20Science/3%20-%20Projeto/04%20-%20American%20Express/notebooks/06-feature_engi.ipynb#X20sZmlsZQ%3D%3D?line=26'>27</a>     return df
#
# File c:\Users\brito\OneDrive\Documentos\1 - Data Science\3 - Projeto\04 - American Express\venv\lib\site-packages\pandas\core\reshape\tile.py:369, in qcut(x, q, labels, retbins, precision, duplicates)
#     315 """
#     316 Quantile-based discretization function.
#     317
#    (...)
#     366 array([0, 0, 1, 2, 3])
#     367 """
#     368 original = x
# --> 369 x = _preprocess_for_cut(x)
#     370 x, dtype = _coerce_to_type(x)
#     372 quantiles = np.linspace(0, 1, q + 1) if is_integer(q) else q
#
# File c:\Users\brito\OneDrive\Documentos\1 - Data Science\3 - Projeto\04 - American Express\venv\lib\site-packages\pandas\core\reshape\tile.py:601, in _preprocess_for_cut(x)
#     599     x = np.asarray(x)
#     600 if x.ndim != 1:
# --> 601     raise ValueError("Input array must be 1 dimensional")
#     603 return x
#
# ValueError: Input array must be 1 dimensional
